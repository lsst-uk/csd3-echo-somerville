# %%
import os

# %%
s3_keys_path = '~/.keys/lsst_keys.json'
swift_keys_path = '~/.keys/lsst-swift-credentials.json'
creds = {}

#for swift
with open(os.path.expanduser(swift_keys_path), 'r') as swiftkeys:
    for line in swiftkeys.readlines():
        if 'user' in line:
            creds['ST_USER'] = line.split('"')[3]
        elif 'secret_key' in line:
            creds['ST_KEY'] = line.split('"')[3]
creds['ST_AUTH'] = 'https://s3.echo.stfc.ac.uk/auth/1.0'

#Some Swift operations expect environment variables
#Here we just mirror the creds dict to the os.environ dict
for k, v in creds.items():
    os.environ[k] = v

# %%
import bucket_manager.bucket_manager as bm

# %% [markdown]
# ## Swift Connection

# %%
connection = bm.get_conn_swift()

# %%
# %%timeit
containers = [ container['name'] for container in connection.get_account()[1] ]

# %%
for i, container in enumerate(containers):
    print(i, container)
# Out:
# 0 DRP
# 1 LSST-IR-FUSION
# 2 LSST-IR-FUSION-Butlers
# 3 LSST-IR-FUSION-TEST
# 4 LSST-IR-FUSION-rdsip005
# 5 LSST-IR-FUSION-test-zip-processing
# 6 LSST-IR-FUSION-testfromopenstack
# 7 LSST-IR-FUSION_gen3_conversion
# 8 dmu4
# 9 lsst-dac
# 10 lsst-drp-config
# 11 lsst-test

# %%
container = containers[2]
print(container)
# Out:
# LSST-IR-FUSION-Butlers

# %%
import numpy as np

# %%
# %%timeit
with open('temp_filelist.csv', 'w') as f:
    f.write('name\n')
    num_obj = 0
    for _ in connection.get_container(container, full_listing=True)[1]:
        num_obj+=1
    print(num_obj)
    for i in np.arange(0, num_obj, 100000):
        print(i)
        for obj in connection.get_container(container, full_listing=True, limit=100000, marker=i)[1]:
            f.write(obj['name'] + '\n')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[24], line 4
#       2 with open('temp_filelist.csv', 'w') as f:
#       3     f.write('name\n')
# ----> 4     num_obj = len(connection.get_container(container, full_listing=True)[1])
#       5     print(num_obj)
#       6     for i in np.arange(0, num_obj, 100000):
#
# File ~/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/swiftclient/client.py:1883, in Connection.get_container(self, container, marker, limit, prefix, delimiter, end_marker, version_marker, path, full_listing, headers, query_string)
#    1879 """Wrapper for :func:`get_container`"""
#    1880 # TODO(unknown): With full_listing=True this will restart the entire
#    1881 # listing with each retry. Need to make a better version that just
#    1882 # retries where it left off.
# -> 1883 return self._retry(None, get_container, container, marker=marker,
#    1884                    limit=limit, prefix=prefix, delimiter=delimiter,
#    1885                    end_marker=end_marker,
#    1886                    version_marker=version_marker, path=path,
#    1887                    full_listing=full_listing, headers=headers,
#    1888                    query_string=query_string)
#
# File ~/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/swiftclient/client.py:1797, in Connection._retry(self, reset_func, func, *args, **kwargs)
#    1795 if caller_response_dict is not None:
#    1796     kwargs['response_dict'] = {}
# -> 1797 rv = func(self.url, self.token, *args,
#    1798           service_token=self.service_token, **kwargs)
#    1799 self._add_response_dict(caller_response_dict, kwargs)
#    1800 return rv
#
# File ~/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/swiftclient/client.py:970, in get_container(url, token, container, marker, limit, prefix, delimiter, end_marker, version_marker, path, http_conn, full_listing, service_token, headers, query_string)
#     968     marker = listing[-1].get('name', listing[-1].get('subdir'))
#     969 version_marker = listing[-1].get('version_id')
# --> 970 listing = get_container(url, token, container, marker, limit,
#     971                         prefix, delimiter, end_marker,
#     972                         version_marker, path, http_conn,
#     973                         service_token=service_token,
#     974                         headers=headers)[1]
#     975 if listing:
#     976     rv[1].extend(listing)
#
# File ~/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/swiftclient/client.py:1003, in get_container(url, token, container, marker, limit, prefix, delimiter, end_marker, version_marker, path, http_conn, full_listing, service_token, headers, query_string)
#    1001     req_headers.update(headers)
#    1002 method = 'GET'
# -> 1003 conn.request(method, '%s?%s' % (cont_path, qs), '', req_headers)
#    1004 resp = conn.getresponse()
#    1005 body = resp.read()
#
# File ~/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/swiftclient/client.py:416, in HTTPConnection.request(self, method, full_path, data, headers, files)
#     411     headers['user-agent'] = self.default_user_agent
#     412 url = "%s://%s%s" % (
#     413     self.parsed_url.scheme,
#     414     self.parsed_url.netloc,
#     415     full_path)
# --> 416 self.resp = self._request(method, url, headers=headers, data=data,
#     417                           files=files, **self.requests_args)
#     418 return self.resp
#
# File ~/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/swiftclient/client.py:400, in HTTPConnection._request(self, *arg, **kwarg)
#     398 def _request(self, *arg, **kwarg):
#     399     """Final wrapper before requests call, to be patched in tests"""
# --> 400     return self.request_session.request(*arg, **kwarg)
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     483     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#     501     raise ConnectionError(err, request=request)
#
# File ~/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/urllib3/connectionpool.py:791, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 response_conn = conn if not release_conn else None
#     790 # Make the request on the HTTPConnection object
# --> 791 response = self._make_request(
#     792     conn,
#     793     method,
#     794     url,
#     795     timeout=timeout_obj,
#     796     body=body,
#     797     headers=headers,
#     798     chunked=chunked,
#     799     retries=retries,
#     800     response_conn=response_conn,
#     801     preload_content=preload_content,
#     802     decode_content=decode_content,
#     803     **response_kw,
#     804 )
#     806 # Everything went great!
#     807 clean_exit = True
#
# File ~/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/urllib3/connectionpool.py:537, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 # Receive the response from the server
#     536 try:
# --> 537     response = conn.getresponse()
#     538 except (BaseSSLError, OSError) as e:
#     539     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File ~/miniconda3/envs/lsst-uk/lib/python3.10/http/client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~/miniconda3/envs/lsst-uk/lib/python3.10/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~/miniconda3/envs/lsst-uk/lib/python3.10/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~/miniconda3/envs/lsst-uk/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~/miniconda3/envs/lsst-uk/lib/python3.10/ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File ~/miniconda3/envs/lsst-uk/lib/python3.10/ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:
# 2025-03-10 16:47:31,532 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-03-10 16:47:31,532 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-03-10 16:47:31,532 - distributed.nanny - ERROR - Worker process died unexpectedly
# 2025-03-10 16:47:31,532 - distributed.nanny - ERROR - Worker process died unexpectedly
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# Process Dask Worker process (from Nanny):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/distributed/nanny.py", line 1021, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/distributed/nanny.py", line 1021, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/distributed/nanny.py", line 1021, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
# Traceback (most recent call last):
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
# KeyboardInterrupt
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/distributed/nanny.py", line 995, in _run
#     with contextlib.ExitStack() as stack:
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/contextlib.py", line 576, in __exit__
#     raise exc_details[1]
# Traceback (most recent call last):
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/contextlib.py", line 561, in __exit__
#     if cb(*exc_details):
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/contextlib.py", line 449, in _exit_wrapper
#     callback(*args, **kwds)
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/threading.py", line 1100, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/threading.py", line 1116, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
# KeyboardInterrupt
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/distributed/nanny.py", line 995, in _run
#     with contextlib.ExitStack() as stack:
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/contextlib.py", line 576, in __exit__
#     raise exc_details[1]
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/distributed/nanny.py", line 995, in _run
#     with contextlib.ExitStack() as stack:
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/contextlib.py", line 561, in __exit__
#     if cb(*exc_details):
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/contextlib.py", line 576, in __exit__
#     raise exc_details[1]
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/contextlib.py", line 449, in _exit_wrapper
#     callback(*args, **kwds)
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/contextlib.py", line 561, in __exit__
#     if cb(*exc_details):
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/threading.py", line 1100, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/contextlib.py", line 449, in _exit_wrapper
#     callback(*args, **kwds)
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/threading.py", line 1116, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/threading.py", line 1100, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/threading.py", line 1116, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
# KeyboardInterrupt
# KeyboardInterrupt
# Traceback (most recent call last):
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/distributed/nanny.py", line 1021, in _run
#     asyncio_run(run(), loop_factory=get_loop_factory())
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/distributed/compatibility.py", line 236, in asyncio_run
#     return loop.run_until_complete(main)
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/asyncio/base_events.py", line 636, in run_until_complete
#     self.run_forever()
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/asyncio/base_events.py", line 1871, in _run_once
#     event_list = self._selector.select(timeout)
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/selectors.py", line 469, in select
#     fd_event_list = self._selector.poll(timeout, max_ev)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/multiprocessing/process.py", line 314, in _bootstrap
#     self.run()
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/multiprocessing/process.py", line 108, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/distributed/process.py", line 202, in _run
#     target(*args, **kwargs)
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/distributed/nanny.py", line 995, in _run
#     with contextlib.ExitStack() as stack:
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/contextlib.py", line 576, in __exit__
#     raise exc_details[1]
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/contextlib.py", line 561, in __exit__
#     if cb(*exc_details):
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/contextlib.py", line 449, in _exit_wrapper
#     callback(*args, **kwds)
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/threading.py", line 1100, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/home/dave/miniconda3/envs/lsst-uk/lib/python3.10/threading.py", line 1116, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
# KeyboardInterrupt

# %%
from dask import dataframe as ddf
import distributed
client = distributed.Client()
client
# Out:
# /home/dave/miniconda3/envs/lsst-uk/lib/python3.10/site-packages/distributed/node.py:182: UserWarning: Port 8787 is already in use.
# Perhaps you already have a cluster running?
# Hosting the HTTP server on port 32959 instead
#   warnings.warn(
# <Client: 'tcp://127.0.0.1:41597' processes=4 threads=12, memory=7.43 GiB>

# %%
# !wc -l temp_filelist.csv
# Out:
# 13 temp_filelist.csv

# %%
objects_swift_dask = ddf.read_csv('temp_filelist.csv', blocksize=2)

# %%
objects_swift_dask
# Out:
# Dask DataFrame Structure:
#                    name
# npartitions=186
#                  string
#                     ...
# ...                 ...
#                     ...
#                     ...
# Dask Name: read_csv, 1 expression
# Expr=ReadCSV(fcbd71c)

# %%
def delete_obj_swift(obj):
    try:
        connection.delete_object(container, obj)
    except Exception as e:
        return e
    return True

# %%
import pandas as pd

# %%
objects_swift_dask['deleted'] = objects_swift_dask['name'].apply(delete_obj_swift, meta=pd.Series(dtype=bool))

# %%
objects_swift_dask
# Out:
# Dask DataFrame Structure:
#                    name deleted
# npartitions=186
#                  string    bool
#                     ...     ...
# ...                 ...     ...
#                     ...     ...
#                     ...     ...
# Dask Name: assign, 4 expressions
# Expr=Assign(frame=ReadCSV(fcbd71c))

# %%
# %%timeit
objects_swift = objects_swift_dask.compute()

# %%
objects_swift
# Out:
#                              name  deleted
# 0   dummy/collated_4.zip.metadata     True
# 0   dummy/collated_5.zip.metadata     True
# 0  dummy/collated_55.zip.metadata     True
# 0  dummy/collated_59.zip.metadata     True
# 0   dummy/collated_6.zip.metadata     True
# 0  dummy/collated_61.zip.metadata     True
# 0  dummy/collated_62.zip.metadata     True
# 0  dummy/collated_63.zip.metadata     True
# 0  dummy/collated_64.zip.metadata     True
# 0  dummy/collated_65.zip.metadata     True
# 0  dummy/collated_66.zip.metadata     True
# 0   dummy/collated_7.zip.metadata     True
